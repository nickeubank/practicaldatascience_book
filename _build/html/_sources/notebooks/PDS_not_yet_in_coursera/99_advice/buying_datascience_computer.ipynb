# %% [markdown]
# # How To Buy A Computer
#
# ```{raw} html
# <meta http-equiv="refresh" content="0; url=https://dukemids.com/professional_advice/buying_datascience_computer.html">
# <script>window.location.href = "https://dukemids.com/professional_advice/buying_datascience_computer.html";</script>
# ```
#
# This page has moved to the [Duke MIDS site](https://dukemids.com/professional_advice/buying_datascience_computer.html). You will be automatically redirected. If not, please click the link.
