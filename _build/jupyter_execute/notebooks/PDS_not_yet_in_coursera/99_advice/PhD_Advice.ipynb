# %% [markdown]
# # So You're Thinking About a PhD
#
# ```{raw} html
# <meta http-equiv="refresh" content="0; url=https://dukemids.com/professional_advice/PhD_Advice.html">
# <script>window.location.href = "https://dukemids.com/professional_advice/PhD_Advice.html";</script>
# ```
#
# This page has moved to the [Duke MIDS site](https://dukemids.com/professional_advice/PhD_Advice.html). You will be automatically redirected. If not, please click the link.
