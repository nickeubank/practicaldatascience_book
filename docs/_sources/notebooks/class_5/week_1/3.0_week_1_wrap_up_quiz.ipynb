# %% [markdown]
# # Module 1 Wrap-up Quiz

# %% [markdown]
# Over the course of this module, you explored best practices in plotting and learned how to generate plots with Python through `matplotlib`. These skills are invaluable for data science as clearly communicating your findings is a skill that sets great data scientists apart. And you most certainly will need to communicate your findings and do so regularly! In this wrap up quiz, we'll review some of the key concepts from this module.
#
# ## Part 1: Conceptual questions
#
# ### Q1. What is the primary purpose of data visualization?
#
# A. To create complex and intricate plots
# B. To make data more understandable and clearly communicate patterns
# C. To make the plot visually appealing, regardless of clarity
# D. To show as many variables as possible in one chart
#
# (Correct answer: B)
#
# ### Q2. Which type of plot is generally best for showing the relationship between two continuous variables (e.g. height and weight)?
#
# A. Histogram
# B. Bar chart
# C. Scatter plot
# D. Pie chart
#
# (Correct answer: C)
#
# ### Q3. What is the primary reason that it is important to label axes on a plot?
#
# A. It makes the plot look more professional
# B. It ensures the reader knows what each axis represents
# C. It’s optional and can be skipped to simplify the plot
# D. It prevents the need for a legend
#
# (Correct answer: B)
#
# ### Q4. Which of the following statements best describes the role of a legend in a plot?
#
# A. It is decorative and can be used to add colors
# B. It is only useful if there are more than two series in the data
# C. It explains symbols, colors, or lines to clarify the data for the reader
# D. It is necessary for all plots, regardless of content
#
# (Correct answer: C)
#
# ### Q5. What should be the top consideration when selecting a color palette for a plot?
#
# A. Only colors that match corporate branding
# B. Colors that are easily distinguishable and accessible to all readers, including colorblind readers
# C. Colors that match the data points
# D. The brightest colors available for visibility
#
# (Correct answer: B)
#
# ### Q6. In bar blots, where should I set the baseline for the bar?
#
# A. At the value 0.
# B. At the minimum value in the dataset being plotted.
# C. At the maximum value in the dataset being plotted.
# D. Wherever it best highlights the point you are trying to make.
#
# (Correct answer: A)
#
# ### Q7. In which of the following is it easiest for humans to perceive differences between data?
#
# A. Color hue
# B. Volume
# C. Position along a scale
# D. Angle
# E. Length
# F. Area
#
# (Correct answer: C)

# %% [markdown]
# ## Part 2: Applied questions
#
# In this section, you'll be referring back to the exercises you completed along the way.
#
# ## 2a. Anscombe's Quartet
#
# In step 5 of this exercise you were asked to note the patterns of each of the datasets you plotted and their corresponding summary statistics. Please answer the following questions based on those plots.
#
# ### Q8. In **dataset 1** of step 5, what was the pattern revealed in the scatter plot of the data?
#
# A. A single circle.
# B. Two circles, one inside the other.
# C. A grid of 9 clusters of dots.
# D. Five parallel diagonal lines stretching from the lower left to upper right.
# E. Five parallel horizontal lines stretching from the left to right.
# F. Four Parallel vertical lines stretching from the top to the bottom.
# G. A 5-pointed star.
# H. Two fuzzy vertical lines.
# I. A cow.
# J. A dinosaur.
# K. A cat.
# L. An "X".
#
# (Correct answer: J)
#
# ### Q9. In **dataset 6** of step 5, what was the pattern revealed in the scatter plot of the data?
#
# A. A single circle.
# B. Two circles, one inside the other.
# C. A grid of 9 clusters of dots.
# D. Five parallel diagonal lines stretching from the lower left to upper right.
# E. Five parallel horizontal lines stretching from the left to right.
# F. Four Parallel vertical lines stretching from the top to the bottom.
# G. A 5-pointed star.
# H. Two fuzzy vertical lines.
# I. A cow.
# J. A dinosaur.
# K. A cat.
# L. An "X".
#
# (Correct answer: G)
#
# ### Q10. In **dataset 10** of step 5, what was the pattern revealed in the scatter plot of the data?
#
# A. A single circle.
# B. Two circles, one inside the other.
# C. A grid of 9 clusters of dots.
# D. Five parallel diagonal lines stretching from the lower left to upper right.
# E. Five parallel horizontal lines stretching from the left to right.
# F. Four Parallel vertical lines stretching from the top to the bottom.
# G. A 5-pointed star.
# H. Two fuzzy vertical lines.
# I. A cow.
# J. A dinosaur.
# K. A cat.
# L. An "X".
#
# (Correct answer: B)
#
# ### Q11. In datasets from the Anscombe's Quartet exercises, which of the following statistics showed any differences at 3 decimal places of precision (meaning, 15.67 is the same as 15.68 since they both round to 15.7; 15.6 would be considered different from 15.5 however)?
#
# A. Mean of x
# B. Mean of y
# C. Standard deviation of x
# D. Standard deviation of y
# E. None of the above
#
# (Correct answer: E)

# %% [markdown]
# ## 2b. Creating a Series of Timeseries
#
# ### Q12. Viewing the plots from this exercise, which of the following most accurately represents the trends in literacy from 1820 to 2020?
#
# A. Decreased from 61% to 22%
# B. Decreased from 84% to 63%
# C. Increased from 60% to 90%
# D. Increased from 12% to 87%
# E. Remained relatively stable over that period
#
# (Correct answer: D)
